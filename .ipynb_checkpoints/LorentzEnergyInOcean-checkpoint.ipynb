# %% [markdown]
# ## Conversion terms
#
# ### Mean Available Potential Energy to Mean Kinetic Energy
# $$C(P_m,K_m) = - \int_V g {\overline{\rho}}\,{\overline{w}} dV $$
#
# ### Eddy Available Potential Energy to Eddy Kinetic Energy
# $$C(P_e,K_e) = - \int_V g \overline{\rho' w'} dV$$
#
# ### Eddy Kinetic Energy to Mean Kinetic Energy
#
# $$C(K_e,K_m) = \int_V (\rho_o \overline{u'\boldsymbol{u'}}  \nabla \overline{u} + \rho_o \overline{v'\boldsymbol{u'}}. \nabla\overline{v}) dV $$
#
# ### Eddy Available Potential Energy to Mean Available Potential Energy
#
# $$C(P_e,P_m) = - \int_V \frac{g}{n_o} \overline{\rho'\boldsymbol{u'}}. \nabla_h \overline{\rho} dV$$
#
#
# ## Generation Terms
#
# ### Generation of Mean Available Potential Energy
#
# $$ G(P_m) = - \int_S g \frac{\alpha_{o,1}}{n_o} \overline{J}_s \overline{\rho*} dS  - \int_S g \frac{\beta_{o,1}}{n_o} \overline{G}_s \overline{\rho*} dS$$
#
# here J is surface temperature flux<br>
# G is surface salinity flux <br>
# $\alpha_{o,1}$ and $\beta_{o,1} $ are coefficient of expansions at the top layer<br>
#
# $J_s = \frac{H}{\rho_s c} $ and H is surface heat flux <br>
# $G_s = S_1(E - P) $ <br>
# E is evaporation and P is precipitation
#
# $S_1$ is the surface salinity </br>
#
# $\rho* = \rho - \rho_{ref}$ <br>
# $\rho_{ref} = \langle\overline{\rho}\rangle $ where $\langle ... \rangle $ refer to area averaging <br>
#
# ### Generation of mean Kinetic Energy
#
# $$G(K_m) = \int_S(\overline{\tau_x}\,\overline{u} + \overline{\tau_y}\,\overline{v})\, dS $$
#
# ### Generation of Eddy Kinetic Energy
#
# $$G(K_e) = \int_S(\overline{\tau_x' \,u'} + \overline{\tau_y' \,v'})\, dS $$
#
# ### Generation of Eddy Available Potential Energy
# $$ G(P_e) = - \int_S g \frac{\alpha_{o,1}}{n_o} \overline{J_s' \rho'} dS  - \int_S g \frac{\beta_{o,1}}{n_o} \overline{G_s' \rho'} dS$$
#
#
# ## Energy reservoirs
#
# ### Mean Potential Energy

# %% [markdown]
# ## Fields to be writtten from POP2 Output
#
# ### Primes to be calculated
# $ \overline{\rho'\boldsymbol{u'}} $ <br>
# $ \overline{u'\boldsymbol{u'}}  = \overline{u'u'} + \overline{u'v'} +\overline{u'w'} $ <br>
# $ \overline{v'\boldsymbol{u'}}  = \overline{v'u'} + \overline{v'v'} +\overline{v'w'} $ <br>
# $ \overline{\rho'w'}$ <br>
# $ \overline{J_s'\rho'} $ <br>
# $ \overline{G_s'\rho'} $ <br>
# $ \overline{\tau_x'u'} $ <br>
# $ \overline{\tau_y'v'} $ <br>

# %% [markdown]
# ## On the value of $n_o$ and Assumptions made for $\varrho,\; \alpha,\; and \;\beta$
#
# $$ \frac{d\rho}{dt} = \left(\frac{\partial \rho }{\partial \theta}\right)_{p,S}
# \frac{d\theta}{dt} + \left(\frac{\partial \rho}{\partial S}\right)_{p,\theta}\frac{dS}{dt} + \left(\frac{\partial \rho}{\partial z}\right)_{\theta,S} w $$
#
# $$ \frac{d \theta}{dt} = \frac{\partial J}{\partial z}  \;  and \; \frac{dS}{dt} = \frac{\partial G}{\partial z} $$
#
# This gives us <br>
#
# $$ \frac{\partial \rho}{\partial t} +
#    \boldsymbol{u_h} . \nabla_h \rho  +
#    w \left( \frac{\partial \rho }{\partial z} -
#    \left( \frac{\partial \rho }{\partial z}\right)_{S,\theta} \right)
#    = \left(\frac{\partial \rho}{\partial \theta} \right)_{S,p} \frac{\partial J}{\partial z}  +
#    \left(\frac{\partial \rho }{\partial S} \right)_{S, \theta} \frac{\partial G}{\partial z}
# $$
#
# $$ \frac{\partial \rho}{\partial t} +
#    \boldsymbol{u_h} . \nabla_h \rho  +
#    w \left( \frac{\partial \varrho}{\partial z} \right)
#    = \alpha_o(\lambda,\phi,z) \frac{\partial J}{\partial z}  +
#    \beta_o(\lambda,\phi,z) \frac{\partial G}{\partial z}
# $$
#
# $$\frac{\partial \rho }{\partial z} -
#    \left( \frac{\partial \rho }{\partial z}\right)_{S,\theta} =
#    \frac{\partial \varrho}{\partial z}  $$ is vertial local potential density gradient
#
# $$ \frac{\partial \varrho}{\partial z} \approx \frac{\partial \langle \overline{\varrho} \rangle}{\partial z} = n_o(z) $$
#
# $$ \left(\frac{\partial \rho}{\partial \theta} \right)_{S,p} \approx
# \left(\frac{\partial \overline{\rho}}{\partial \theta} \right)_{S,p} = \alpha_o(\lambda,\phi,z)$$
#
# $$ \left(\frac{\partial \rho}{\partial S} \right)_{\theta,p} \approx
# \left(\frac{\partial \overline{\rho}}{\partial S} \right)_{\theta,p} = \beta_o(\lambda,\phi,z)$$
#
# ## The value of $\alpha$ and $\beta$ used in POP2 in linear Equation of State
# $$ \alpha_o  = \left (\frac{\partial \rho}{\partial T}\right)_{S,p} = 2.55 \times 10^{-4} gr/cm^3/K $$
# $$ \beta_o = \left (\frac{\partial \rho}{\partial S}\right)_{T,p} = 7.64\times 10^-1 gr/cm^3/msu $$
#
# $$ 1 gram/kg = 0.001 msu $$

# %%
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime

filename = 'flt_HIGH_PASS.pop.h.0009-01-05.nc'

dataset = Dataset(filename)

# %%
print(
'UVEL', dataset.variables['UVEL'].units, dataset.variables['UVEL'].long_name,'\n',
'VVEL', dataset.variables['VVEL'].units, dataset.variables['VVEL'].long_name,'\n',
'WVEL', dataset.variables['WVEL'].units, dataset.variables['WVEL'].long_name,'\n',
'TAUX', dataset.variables['TAUX'].units, dataset.variables['TAUX'].long_name,'\n',
'TAUY', dataset.variables['TAUY'].units, dataset.variables['TAUY'].long_name,'\n',
'RHO', dataset.variables['RHO'].units, dataset.variables['RHO'].long_name,'\n',
'PD', dataset.variables['PD'].units, dataset.variables['PD'].long_name,'\n',
'SHF', dataset.variables['SHF'].units, dataset.variables['SHF'].long_name,'\n',
'cp_sw', dataset.variables['cp_sw'].units, dataset.variables['cp_sw'].long_name,'\n',
'rho_sw', dataset.variables['rho_sw'].units, dataset.variables['rho_sw'].long_name,'\n',
'SALT', dataset.variables['SALT'].units, dataset.variables['SALT'].long_name,'\n',
'rho_fw', dataset.variables['rho_sw'].units, dataset.variables['rho_sw'].long_name,'\n',
'EVAP_F', dataset.variables['EVAP_F'].units, dataset.variables['EVAP_F'].long_name,'\n',
'PREC_F', dataset.variables['PREC_F'].units, dataset.variables['PREC_F'].long_name,'\n',
'SALT_F',dataset.variables['SALT_F'].units, dataset.variables['SALT_F'].long_name,'\n',
'MELT_F',dataset.variables['MELT_F'].units, dataset.variables['MELT_F'].long_name,'\n')
# Out:
# UVEL centimeter/s Velocity in grid-x direction
#  VVEL centimeter/s Velocity in grid-y direction
#  WVEL centimeter/s Vertical Velocity
#  TAUX dyne/centimeter^2 Windstress in grid-x direction
#  TAUY dyne/centimeter^2 Windstress in grid-y direction
#  RHO gram/centimeter^3 In-Situ Density
#  PD gram/centimeter^3 Potential Density Ref to Surface
#  SHF watt/m^2 Total Surface Heat Flux, Including SW
#  cp_sw erg/g/K Specific Heat of Sea Water
#  rho_sw gram/centimeter^3 Density of Sea Water
#  SALT gram/kilogram Salinity
#  rho_fw gram/centimeter^3 Density of Sea Water
#  EVAP_F kg/m^2/s Evaporation Flux from Coupler
#  PREC_F kg/m^2/s Precipitation Flux from Cpl (rain+snow)
#  SALT_F kg/m^2/s Salt Flux from Coupler (kg of salt/m^2/s)
#  MELT_F kg/m^2/s Melt Flux from Coupler

# %% [markdown]
# ### Before averaging the products to be calculated are:
#
# - $\rho u , \rho v, \rho w $
# - $uu, uv , uw $
# - $vu, vv , vw $
# - $\tau_x u, \tau_y v $
# - $J_s \rho $
# - $G_s \rho $

# %%
temp = Dataset('temp.nc')

# %%
temp.variables.keys()
# Out:
# odict_keys(['UV', 'J', 'time_bound', 'time', 'z_t', 'z_t_150m', 'z_w', 'z_w_top', 'z_w_bot', 'dz', 'dzw', 'ULONG', 'ULAT', 'TLONG', 'TLAT', 'KMT', 'KMU', 'REGION_MASK', 'UAREA', 'TAREA', 'HU', 'HT', 'DXU', 'DYU', 'DXT', 'DYT', 'HTN', 'HTE', 'HUS', 'HUW', 'ANGLE', 'ANGLET', 'days_in_norm_year', 'grav', 'omega', 'radius', 'cp_sw', 'sound', 'vonkar', 'cp_air', 'rho_air', 'rho_sw', 'rho_fw', 'stefan_boltzmann', 'latent_heat_vapor', 'latent_heat_fusion', 'ocn_ref_salinity', 'sea_ice_salinity', 'T0_Kelvin', 'salt_to_ppt', 'ppt_to_salt', 'mass_to_Sv', 'heat_to_PW', 'salt_to_Svppt', 'salt_to_mmday', 'momentum_factor', 'hflux_factor', 'fwflux_factor', 'salinity_factor', 'sflux_factor', 'nsurface_t', 'nsurface_u', 'UVEL', 'VVEL', 'KE', 'TEMP', 'SALT', 'RHO', 'SSH', 'SSH2', 'SHF', 'SHF_QSW', 'SFWF', 'TAUX', 'TAUY', 'EVAP_F', 'PREC_F', 'SNOW_F', 'MELT_F', 'ROFF_F', 'SALT_F', 'SENH_F', 'LWUP_F', 'LWDN_F', 'MELTH_F', 'IAGE', 'WVEL', 'UET', 'VNT', 'PD', 'HMXL', 'XMXL', 'TMXL', 'HBLT', 'XBLT', 'TBLT
# ...

# %%
J = np.array(temp.variables['J'])
SHF = np.array(temp.variables['SHF'])
cp_sw = np.array(temp.variables['cp_sw'])
rho_sw = np.array(temp.variables['rho_sw'])

# %%
Jc = SHF*1e7/(cp_sw*rho_sw)
print(cp_sw)
print(rho_sw)
print(np.max(SHF))
# Out:
# 39960000.0
# 1.026
# 9.96921e+36
# /Users/ckhr.rai/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: overflow encountered in multiply
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(18,9))
plt.subplot(121)
plt.pcolormesh(J[0,:,:])
plt.clim(-400,80)
plt.colorbar()
plt.subplot(122)
plt.pcolormesh(Jc[0,:,:])
plt.clim(-400,80)
plt.colorbar()

# %%
salt = np.array(dataset.variables['SALT'])

# %%
np.shape(salt)
# Out:
# (1, 100, 800, 1200)

# %%
from getProdFields import writeWithProdFields
writeWithProdFields('flt_HIGH_PASS.pop.h.0009-01-05.nc')
# Out:
# Reading file at date
# 0009-01-06
# /Volumes/Storage/POPdataHandling/getProdFields.py:96: RuntimeWarning: overflow encountered in multiply
#   RHO_UVEL = RHO * UVEL
# /Volumes/Storage/POPdataHandling/getProdFields.py:97: RuntimeWarning: overflow encountered in multiply
#   RHO_VVEL = RHO * VVEL
# /Volumes/Storage/POPdataHandling/getProdFields.py:98: RuntimeWarning: overflow encountered in multiply
#   RHO_WVEL = RHO * WVEL
# /Volumes/Storage/POPdataHandling/getProdFields.py:100: RuntimeWarning: overflow encountered in multiply
#   UVEL_UVEL = UVEL*UVEL
# /Volumes/Storage/POPdataHandling/getProdFields.py:101: RuntimeWarning: overflow encountered in multiply
#   UVEL_VVEL = UVEL*VVEL
# /Volumes/Storage/POPdataHandling/getProdFields.py:102: RuntimeWarning: overflow encountered in multiply
#   UVEL_WVEL = UVEL*WVEL
# /Volumes/Storage/POPdataHandling/getProdFields.py:104: RuntimeWarning: overflow encountered in multiply
#   VVEL_VVEL = VVEL*VVEL
# ...

# %%
prd_dataset = Dataset('ProductFields_0009-01-06.nc')
prd_dataset.variables.keys()
# Out:
# odict_keys(['time', 'RHO_UVEL', 'RHO_VVEL', 'RHO_WVEL', 'UVEL_UVEL', 'UVEL_VVEL', 'UVEL_WVEL', 'VVEL_VVEL', 'VVEL_WVEL', 'Js_RHO', 'Gs_RHO', 'TAUX_UVEL', 'TAUY_VVEL'])

# %%
ls
